# %%
import pandas as pd

# %%
foot=pd.read_csv('../Data/gajok.csv')
addresses=list(foot['Address'])

# %%
url='https://maps.googleapis.com/maps/api/geocode/json?address={addr}'
header={'key':'AIzaSyC5BM4rYTLafiyYCjl_IlaT7we__p9R7fw'}

# %%
import time
import urllib.request
import json

# %%
len(addresses)
# Out:
# 403

# %%
encText =urllib.parse.quote(addresses[0])
url = 'https://maps.googleapis.com/maps/api/geocode/json?address='+ encText + "&key=AIzaSyC5BM4rYTLafiyYCjl_IlaT7we__p9R7fw"
request = urllib.request.Request(url)
# request.add_header("key",'AIzaSyC5BM4rYTLafiyYCjl_IlaT7we__p9R7fw')
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    entext = response_body.decode('utf-8')
else:
    print("Error Code:" + rescode)

data = json.loads(entext)
print(data)
# Out:
# {'results': [{'address_components': [{'long_name': 'Seocho-daero 73-gil', 'short_name': 'Seocho-daero 73-gil', 'types': ['political', 'sublocality', 'sublocality_level_4']}, {'long_name': 'Seocho-gu', 'short_name': 'Seocho-gu', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Seoul', 'short_name': 'Seoul', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'South Korea', 'short_name': 'KR', 'types': ['country', 'political']}, {'long_name': '137-074', 'short_name': '137-074', 'types': ['postal_code']}], 'formatted_address': 'Seocho-daero 73-gil, Seocho-gu, Seoul, South Korea', 'geometry': {'bounds': {'northeast': {'lat': 37.5023997, 'lng': 127.0257229}, 'southwest': {'lat': 37.498097, 'lng': 127.0236558}}, 'location': {'lat': 37.4999104, 'lng': 127.0247106}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 37.5023997, 'lng': 127.0260383302915}, 'southwest': {'lat': 37.498097, 'lng': 127.0233403697085}}}, 'partial_match':
# ...

# %%
lat = []
lng = []
wrong = []
index = 0
index_list = []
for address in addresses:
    try:
        encText =urllib.parse.quote(address)
        url = 'https://maps.googleapis.com/maps/api/geocode/json?address='+ encText + "&key=AIzaSyC5BM4rYTLafiyYCjl_IlaT7we__p9R7fw"
        request = urllib.request.Request(url)
        response = urllib.request.urlopen(request)
        rescode = response.getcode()
        if(rescode==200):
            response_body = response.read()
            entext = response_body.decode('utf-8')
        else:
            print("Error Code:" + rescode)
        
        data = json.loads(entext)
        lat.append(data['results'][0]['geometry']['location']['lat'])
        lng.append(data['results'][0]['geometry']['location']['lng'])
        index += 1
    except Exception as e:
        print(e)
        print(address)
        wrong.append(address)
        index_list.append(index)
        lat.append('')
        lng.append('')
        index += 1

print(lat , lng , wrong, index_list)
print(len(lat),len(lng))
# Out:
# list index out of range
# 세종시 새롬중앙로34 크리스마스빌딩 1층
# list index out of range
# 세종시 마음로 240(고운동)
# list index out of range
# 세종시 한누리대로 2149 엔젤타워 1층(보람동)
# list index out of range
# 대구광역시 달성군 유가면 테크노상업로 4길 12, 102호(봉리)
# ...

# %%
pd.Series(lat)
pd.Series(lng)
foot=pd.concat([foot,pd.Series(lat),pd.Series(lng)],axis=1)

# %%
foot.rename(columns={0:'lat',1:'lng'},inplace=True)

# %%
foot
# Out:
#        Name                       Address           Phone  \
# 0     강남1호점       서울시 서초구 서초대로73길 42(서초동)     02-595-5849
# 1      선정릉점      서울특별시 강남구 봉은사로57길 5(삼성동)     02-543-5849
# 2    한남오거리점      서울시 용산구 한남대로 21길 32(한남동)     02-797-1231
# 3       일원점        서울시 강남구 일원로 9길 55(일원동)    02-3412-0070
# 4      뚝섬역점          서울시 성동구 상원1길 42(성수동)     02-468-7535
# ..      ...                           ...             ...
# 398   진주호탄점               경상남도 진주시 가호로 48    055-761-7989
# 399   전남무안점        전남 무안읍 무안읍 불무로 42(교촌리)    061-454-5849
# 400   경남사천점         경남 사천시 사천읍 평화리 46-6번지    055-854-5445
# 401   경주외동점       경북 경주시 외동읍 입실로 107(입실리)   054-777-4123
# 402   순천오천점  전남 순천시 오천6길 16, 정원타워 1층(오천동)    061-741-5849
#
#                                                  Image        lat         lng
# 0             https://gajok.kr/upload/store/none01.png   37.49991  127.024711
# 1             https://gajok.kr/upload/store/none01.png  37.511192  127.045113
# ...

# %%
foot[foot['lng'] == '']
# Out:
#       Name                               Address         Phone  \
# 55   세종새롬점                세종시 새롬중앙로34 크리스마스빌딩 1층  044-868-1321
# 243  세종고운점                      세종시 마음로 240(고운동)  044-864-4424
# 248  세종보람점           세종시 한누리대로 2149 엔젤타워 1층(보람동)  044-865-5849
# 383  대구현풍점  대구광역시 달성군 유가면 테크노상업로 4길 12, 102호(봉리)  053-615-9893
#
#                                               Image lat lng
# 55         https://gajok.kr/upload/store/none01.png
# 243  https://gajok.kr/upload/store/tpwhdrhdns01.png
# 248        https://gajok.kr/upload/store/none01.png
# 383        https://gajok.kr/upload/store/none01.png

# %%
foot[foot['lat'] == '']
# Out:
#       Name                               Address         Phone  \
# 55   세종새롬점                세종시 새롬중앙로34 크리스마스빌딩 1층  044-868-1321
# 243  세종고운점                      세종시 마음로 240(고운동)  044-864-4424
# 248  세종보람점           세종시 한누리대로 2149 엔젤타워 1층(보람동)  044-865-5849
# 383  대구현풍점  대구광역시 달성군 유가면 테크노상업로 4길 12, 102호(봉리)  053-615-9893
#
#                                               Image lat lng
# 55         https://gajok.kr/upload/store/none01.png
# 243  https://gajok.kr/upload/store/tpwhdrhdns01.png
# 248        https://gajok.kr/upload/store/none01.png
# 383        https://gajok.kr/upload/store/none01.png

# %%
foot=foot[~(foot['lat'] == '')]

# %%
foot.head()
# Out:
#      Name                   Address         Phone  \
# 0   강남1호점   서울시 서초구 서초대로73길 42(서초동)   02-595-5849
# 1    선정릉점  서울특별시 강남구 봉은사로57길 5(삼성동)   02-543-5849
# 2  한남오거리점  서울시 용산구 한남대로 21길 32(한남동)   02-797-1231
# 3     일원점    서울시 강남구 일원로 9길 55(일원동)  02-3412-0070
# 4    뚝섬역점      서울시 성동구 상원1길 42(성수동)   02-468-7535
#
#                                               Image        lat         lng
# 0          https://gajok.kr/upload/store/none01.png   37.49991  127.024711
# 1          https://gajok.kr/upload/store/none01.png  37.511192  127.045113
# 2  https://gajok.kr/upload/store/gksskadhrjfl01.png  37.533519  127.006206
# 3       https://gajok.kr/upload/store/dlfdnjs01.png  37.490705  127.085954
# 4          https://gajok.kr/upload/store/none01.png  37.547014  127.047119

# %%
import folium
from folium.plugins import MarkerCluster

# %%
mc = MarkerCluster()
map = folium.Map(
    location=[37.55, 126.98],
    tiles='Stamen Terrain',
    zoom_start=12
)

for name, address , phone , lat , lng in zip(foot.Name,foot.Address,foot.Phone,foot.lat,foot.lng):
    mc.add_child(
        folium.Marker(
            [lat, lng],
            popup = folium.Popup(
                f'<pred><h6>{name}</h6></pred> <h6>주소 : {address}</h6> <h6>전화번호 : {phone}</h6>',
                max_width=200,
            ),
            # tooltip=name,
            # icon = folium.Icon(color = color)
        )
    )
    
map.add_child(mc)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
